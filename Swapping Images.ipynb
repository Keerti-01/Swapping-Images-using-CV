# %%
import cv2

# %%
img1=cv2.imread('john.jpg')

# %%
img2=cv2.imread('hulk.jpg')

# %%
img4=cv2.imread('john.jpg')

# %%
plt.imshow(img4)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
r1=img4[50:170,200:320]

# %%
plt.imshow(r1)

# %%
img3=cv2.resize(img2,(600,700))

# %%
plt.imshow(img3)

# %%
r2=img3[200:320,240:360]

# %%
plt.imshow(r2)

# %%
r1.shape
# Out:
# (120, 120, 3)

# %%
r2.shape
# Out:
# (120, 120, 3)

# %%
img1[50:170,200:320]=r2

# %%
img3[200:320,240:360]=r1

# %%
plt.imshow(img3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img3)
